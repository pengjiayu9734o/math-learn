# %%
# %load_ext autoreload
# %autoreload 2
from vector_drawing import *
from math import sqrt

# %%
dino_vectors = [(6,4), (3,1), (1,2), (-1,5), (-2,5), (-3,4), (-4,4),
    (-5,3), (-5,2), (-2,2), (-5,1), (-4,0), (-2,1), (-1,0), (0,-3),
    (-1,-4), (1,-4), (2,-3), (1,-2), (3,-1), (5,1)
]

draw(
    Points(*dino_vectors)
)

# %%
arrow_vectors = (2,-2)
draw(
    Arrow(arrow_vectors,(0,0),blue)
)

# %%
parabolic_vectors=[(x,x*x) for x in range (-10,11)]
draw(
    Points(*parabolic_vectors),grid=(1,10),nice_aspect_ratio=False
)

# %%
def add(*vectors):
    return sum([v[0] for v in vectors]),sum([v[1] for v in vectors])

# %%
a=[1,2]
b=[2,3]
c=[3,4]
add(a,b,c)
# Out:
# (6, 9)

# %%
def add(vector1,vector2):
    return vector1[0]+vector2[0],vector1[1]+vector2[1]

# %%
def translate(translation,*vectors):
    return [add(translation,v) for v in vectors]

# %%
translation=1,1
vectors=([0,0],[0,1],[-3,-3])
translate(translation,*vectors)
# Out:
# [(1, 1), (1, 2), (-2, -2)]

# %%
dino_vectors = [(6,4), (3,1), (1,2), (-1,5), (-2,5), (-3,4), (-4,4),
    (-5,3), (-5,2), (-2,2), (-5,1), (-4,0), (-2,1), (-1,0), (0,-3),
    (-1,-4), (1,-4), (2,-3), (1,-2), (3,-1), (5,1)
]

# %%
def scale(s,v):
    return (s*v[0],s*v[1])

# %%
from random import uniform

# %%
def random_r():
    return uniform(-3,3)
def random_s():
    return uniform(-1,1)
z=(-1,1)
v=(1,1)
posibilities=[add(scale(random_r(),z),scale(random_s(),v)) for i in range(0,500)]
draw(Points(*posibilities))

# %%
def subtract(v1,v2):
    return (v1[0]-v2[0],v1[1]-v2[1])

# %%
def distance(v1,v2):
    vx=subtract(v1,v2)
    return sqrt(vx[0]**2+vx[1]**2)

# %%
def perimeter(vectors):
    distances=[distance(vectors[i],vectors[(i+1)%len(vectors)]) for i in range(0,len(vectors))]
    print(sum(distances))

# %%
perimeter([(1,0),(1,1),(0,1),(0,0)])
# Out:
# 4.0

# %%
perimeter(dino_vectors)
# Out:
# 44.77115093694564

# %%
for n in range(-12,15):
    for m in range(-14,13):
        if(distance((1,-1),(n,m)) == 13 and n>m>0):
            print((n,m))
# Out:
# (13, 4)

# %%
def length(vector):
    return sqrt(vector[0]**2+vector[1]**2)

# %%
print(length((-1.34,2.68)))
# Out:
# 2.9963310898497184

# %%
from math import tan

# %%
print(tan(22/180*pi))
# Out:
# 0.4040262258351568

# %%
def to_cartesian(length,radian):
    return (length*cos(radian),length*sin(radian))

# %%
from math import cos,sin

# %%
polars = [(cos(5*x*pi/500.0),2*pi*x/1000) for x in range(0,1000)]
points = [to_cartesian(*polar) for polar in polars]
draw(Polygon(*points))

# %%
from math import atan2
def to_polar(x,y):
    return (sqrt(x**2+y**2),atan2(y,x))

# %%
def rotate(vector,radian):
    return (vector[0],vector[1]+radian)

# %%
rotation_angle = pi/4
draw(Polygon(*dino_vectors,color=gray))
dino_polar = [to_polar(v[0],v[1]) for v in dino_vectors]
dino_rotation_vectors = []
for v in dino_polar:
    rotation_polar=rotate(v, rotation_angle)
    dino_rotation_vectors.append(to_cartesian(rotation_polar[0],rotation_polar[1]))
draw(Polygon(*dino_rotation_vectors,color=gray))
